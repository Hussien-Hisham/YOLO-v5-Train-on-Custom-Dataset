# %%
# Setup Yolo v5
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v6.1-230-gbf1a6dd Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 38.7/78.2 GB disk)

# %%
# Uppload My DataSet.zip
# unzip my DataSet
# Uppload custom_data.yaml
# !unzip -q ../train_data.zip -d ../

# %%
# Train 
# Train YOLOv5s on custom_data for 60 epochs
# !python train.py --img 640 --batch 5 --epochs 50 --data custom_data.yaml --weights yolov5x.pt --nosave  --cache
# Out:
# train: weights=yolov5x.pt, cfg=, data=custom_data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=50, batch_size=5, imgsz=640, rect=False, resume=False, nosave=True, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# remote: Enumerating objects: 1, done.
# remote: Counting objects: 100% (1/1), done.
# remote: Total 1 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (1/1), done.
# From https://github.com/ultralytics/yolov5
#    07e8437..5580b27  master     -> origin/master
# github: ⚠️ YOLOv5 is out of date by 2 commits. Use `git pull` or `git clone https://github.com/ultralytics/yolov5` to update.
# ...

# %%
#Test on Video
# !python detect.py --weights runs/train/exp7/weights/last.pt --img 640 --conf 0.25 --source ../test.mp4
# Out:
# detect: weights=['runs/train/exp7/weights/last.pt'], source=../test.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-230-gbf1a6dd Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 444 layers, 86200330 parameters, 0 gradients, 204.1 GFLOPs
# video 1/1 (1/2717) /content/test.mp4: 384x640 Done. (0.058s)
# video 1/1 (2/2717) /content/test.mp4: 384x640 Done. (0.057s)
# video 1/1 (3/2717) /content/test.mp4: 384x640 Done. (0.053s)
# video 1/1 (4/2717) /content/test.mp4: 384x640 Done. (0.036s)
# video 1/1 (5/2717) /content/test.mp4: 384x640 Done. (0.035s)
# ...

# %%
# Test on image
# !python detect.py --weights runs/train/exp9/weights/best.pt --img 640 --conf 0.25 --source ../test2.mp4
# Out:
# detect: weights=['runs/train/exp9/weights/best.pt'], source=../test2.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-230-gbf1a6dd Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 444 layers, 86200330 parameters, 0 gradients, 204.1 GFLOPs
# video 1/1 (1/1341) /content/test2.mp4: 384x640 1 bear, Done. (0.065s)
# video 1/1 (2/1341) /content/test2.mp4: 384x640 1 bear, Done. (0.054s)
# video 1/1 (3/1341) /content/test2.mp4: 384x640 1 bear, Done. (0.034s)
# video 1/1 (4/1341) /content/test2.mp4: 384x640 1 bear, Done. (0.033s)
# ...

# %%
# install Wandb
#%pip install -q wandb
#import wandb
#wandb.login()
# Out:
#      |████████████████████████████████| 1.8 MB 37.7 MB/s
#      |████████████████████████████████| 145 kB 70.5 MB/s
#      |████████████████████████████████| 181 kB 73.2 MB/s
#      |████████████████████████████████| 63 kB 1.9 MB/s
# ...
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit: ··········
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True
